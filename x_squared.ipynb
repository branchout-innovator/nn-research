# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Generate training data
X = np.linspace(-1, 1, 200).reshape(-1, 1)
y = X**2

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X, y, epochs=1000, verbose=0)

# Generate predictions
X_test = np.linspace(-1.5, 1.5, 300).reshape(-1, 1)
predictions = model.predict(X_test)

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Training data')
plt.plot(X_test, predictions, 'r', label='Predictions')
plt.plot(X_test, X_test**2, 'g--', label='True function')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Neural Network Approximation of x^2')
plt.show()

# Print the final loss
print(f"Final loss: {history.history['loss'][-1]:.6f}")
# Out:
# 2024-06-29 14:25:39.978556: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-29 14:25:39.982047: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-29 14:25:39.990805: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-29 14:25:40.008489: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-29 14:25:40.008523: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-29 14:25:40.019322: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-29 14:25:40.767165: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/ken/miniconda3/envs/d2l/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Final loss: 0.000021
